# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 01: Read data

# %%
dt = pd.read_excel('house_valuation_data.xlsx')

# %%
dt
# Out:
#      X1 transaction date  X2 house age  \
# 0            2012.916667          32.0
# 1            2012.916667          19.5
# 2            2013.583333          13.3
# 3            2013.500000          13.3
# 4            2012.833333           5.0
# ..                   ...           ...
# 409          2013.000000          13.7
# 410          2012.666667           5.6
# 411          2013.250000          18.8
# 412          2013.000000           8.1
# 413          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %% [markdown]
# ### 02 Basic questions #

# %% [markdown]
# 1. What is the distribution of numerical and categorical variables?

# %%
dt.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148953     17.712560
# std               0.281995     11.392485
# min            2012.666667      0.000000
# 25%            2012.916667      9.025000
# 50%            2013.166667     16.100000
# 75%            2013.416667     28.150000
# max            2013.583333     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# ...

# %% [markdown]
# __Observations__:
# - Most of data is from 2013 (2nd and 3rd quartile)
# - Minimum age of house is 0 (which probably means it is new) and maximum age of house is almost 44 whereas, the median age of house is 16.
# - Minimum MRT distance is 23 (probably kilometer) and maximum nearest MRT distance is 6,488 (probably kilometer) whereas, the median nearest MRT distance is 492 (probably kilometer).
# - Maximum number of convienience stores is 10 and minimum is 0 whereas, median is 4 stores.
# - Minimum price of house is almost 8 and maximum price is almost 118 which suggest the data will be skewed toward right side of the distribution but it is just a hypothesis at the moment. On average the price of house is 38.

# %% [markdown]
# 2. Is there any missing values?

# %% [markdown]
# __Observation__:
# - There is no missing values in the data.

# %% [markdown]
# 3. Correlation matrix. (to just get an idea)

# %%
fig, ax = plt.subplots(figsize=(10,5))
corrMatrix = dt.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# __Observations__:
# - Its bit werid that the nearest MRT distance has a negative impact on the price of house. One possible hypothesis could be the noise and disturbance of MRT maybe the reason of the low price of the house (maybe people don't want buy houses close to these activities and they only do it because its cheap because we have negative correlation there (-0.67))
# - As expected the convinience of the nearby stores have positive impact on the price of house.
# - Interestingly longitude and latitude have an a positive impact on the house (maybe it is because of locality)
# - Its interesting to see that age of house has a negative impact on price (as the house gets older the price goes down) but the impact is very low.
